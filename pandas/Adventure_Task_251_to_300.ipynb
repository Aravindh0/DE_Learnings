# %%
import pandas as pd
import pyodbc

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
connection = pyodbc.connect(
  r'Driver={ODBC Driver 17 for SQL Server};'
  r'Server=localhost;'
  r'Database=AdventureWorks2022;'
  r'Trusted_Connection=yes;'
)

# %%
#class for reading table
class db_reader:
    def read_table(self, table_name, connection, col=None):
        if col:
            query = f"SELECT {', '.join(col)} FROM {table_name}" #', '.join(col) converts the list of columns into a comma-separated string. For example, if col = ['name', 'salary'], ', '.join(col) produces 'name, salary'.
        else:
            query = f"SELECT * FROM {table_name}"
        return pd.read_sql_query(query, connection)

# %%
#class for merging
class merge:
  def merge_tbl(self, t1, t2, join, col = None, col1 = None, col2 = None):
    if col1 and col2:
      return pd.merge(t1, t2, how = join, left_on = col1, right_on = col2)
    elif col:
      return pd.merge(t1, t2, how = join, on = col)

# %%
# 251 Retrieve the list of employees along with their job title and the job title of their manager.

# %%
# 252 Retrieve the list of products and their corresponding product descriptions, filtering out products with a description longer than 100 characters.

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
cat = merge().merge_tbl(p[['ProductID','ProductSubcategoryID','Name', 'ProductModelID']], psc[['ProductSubcategoryID', 'ProductCategoryID']], 'outer', 'ProductSubcategoryID')
cat.head()
# Out:
#    ProductID  ProductSubcategoryID                     Name  ProductModelID  \
# 0      771.0                   1.0  Mountain-100 Silver, 38            19.0
# 1      772.0                   1.0  Mountain-100 Silver, 42            19.0
# 2      773.0                   1.0  Mountain-100 Silver, 44            19.0
# 3      774.0                   1.0  Mountain-100 Silver, 48            19.0
# 4      775.0                   1.0   Mountain-100 Black, 38            19.0
#
#    ProductCategoryID
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0

# %%
d = db_reader().read_table('production.ProductDescription', connection)
d.head()
# Out:
#    ProductDescriptionID                                        Description  \
# 0                     3                                    NEW DESCRIPTION
# 1                     4       Aluminum alloy cups; large diameter spindle.
# 2                     5             Aluminum alloy cups and a hollow axle.
# 3                     8  Suitable for any type of riding, on or off-roa...
# 4                    64  This bike delivers a high-level of performance...
#
#                                 rowguid ModifiedDate
# 0  301EED3A-1A82-4855-99CB-2AFE8290D641   2013-04-30
# 1  DFEBA528-DA11-4650-9D86-CAFDA7294EB0   2013-04-30
# 2  F7178DA7-1A7E-4997-8470-06737181305E   2013-04-30
# 3  8E6746E5-AD97-46E2-BD24-FCEA075C3B52   2013-04-30
# 4  7B1C4E90-85E2-4792-B47B-E0C424E2EC94   2013-04-30

# %%
dc = db_reader().read_table('production.ProductModelProductDescriptionCulture', connection)
dc.head()
# Out:
#    ProductModelID  ProductDescriptionID CultureID ModifiedDate
# 0               1                  1199    en       2013-04-30
# 1               1                  1467    ar       2013-04-30
# 2               1                  1589    fr       2013-04-30
# 3               1                  1712    th       2013-04-30
# 4               1                  1838    he       2013-04-30

# %%
des = merge().merge_tbl(cat[['ProductID','Name','ProductModelID']], dc[['ProductModelID', 'ProductDescriptionID']], 'inner', 'ProductModelID')
des.head()
# Out:
#    ProductID                     Name  ProductModelID  ProductDescriptionID
# 0      771.0  Mountain-100 Silver, 38            19.0                   168
# 1      771.0  Mountain-100 Silver, 38            19.0                  1367
# 2      771.0  Mountain-100 Silver, 38            19.0                  1491
# 3      771.0  Mountain-100 Silver, 38            19.0                  1613
# 4      771.0  Mountain-100 Silver, 38            19.0                  1735

# %%
id = merge().merge_tbl(des[['ProductID','Name','ProductDescriptionID']], d[['ProductDescriptionID', 'Description']], 'inner','ProductDescriptionID')
id.head()
# Out:
#    ProductID                     Name  ProductDescriptionID  \
# 0      771.0  Mountain-100 Silver, 38                   168
# 1      771.0  Mountain-100 Silver, 38                  1367
# 2      771.0  Mountain-100 Silver, 38                  1491
# 3      771.0  Mountain-100 Silver, 38                  1613
# 4      771.0  Mountain-100 Silver, 38                  1735
#
#                                          Description
# 0  Top-of-the-line competition mountain bike. Per...
# 1  دراجة سباقات مخصصة للقيادة في الجبال من أعلى ط...
# 2  VTT de compétition haut de gamme. Plusieurs op...
# 3  สุดยอดจักรยานภูเขาสำหรับการแข่งขัน สมบูรณ์แบบด...
# 4  אופני הרים תחרותיים מהשורה הראשונה. אפשרויות ל...

# %%
id[id['Description'].str.len() > 100].head()
# Out:
#    ProductID                     Name  ProductDescriptionID  \
# 0      771.0  Mountain-100 Silver, 38                   168
# 1      771.0  Mountain-100 Silver, 38                  1367
# 2      771.0  Mountain-100 Silver, 38                  1491
# 3      771.0  Mountain-100 Silver, 38                  1613
# 4      771.0  Mountain-100 Silver, 38                  1735
#
#                                          Description
# 0  Top-of-the-line competition mountain bike. Per...
# 1  دراجة سباقات مخصصة للقيادة في الجبال من أعلى ط...
# 2  VTT de compétition haut de gamme. Plusieurs op...
# 3  สุดยอดจักรยานภูเขาสำหรับการแข่งขัน สมบูรณ์แบบด...
# 4  אופני הרים תחרותיים מהשורה הראשונה. אפשרויות ל...

# %%
# 253 Retrieve the list of orders along with the names of customers who placed those orders, ordered by order date in descending order.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
cus = db_reader().read_table('person.person', connection)
cus.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM      False  None       Ken          J
# 1                 2         EM      False  None     Terri        Lee
# 2                 3         EM      False  None   Roberto       None
# 3                 4         EM      False  None       Rob       None
# 4                 5         EM      False   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion AdditionalContactInfo  \
# 0     Sánchez   None               0                  None
# 1       Duffy   None               1                  None
# 2  Tamburello   None               0                  None
# 3     Walters   None               0                  None
# 4    Erickson   None               0                  None
#
#                                         Demographics  \
# 0  <IndividualSurvey xmlns="http://schemas.micros...
# 1  <IndividualSurvey xmlns="http://schemas.micros...
# ...

# %%
dat = merge().merge_tbl(soh[['SalesOrderID', 'CustomerID', 'OrderDate']], cus[['BusinessEntityID', 'FirstName' ,'LastName']], 'inner', col1 = 'CustomerID', col2 = 'BusinessEntityID').sort_values('OrderDate', ascending=False)
dat.head()
# Out:
#        SalesOrderID  CustomerID  OrderDate  BusinessEntityID  FirstName  \
# 17463         75123       18759 2014-06-30             18759     Joshua
# 17449         75104       17151 2014-06-30             17151       Jose
# 17435         75084       11078 2014-06-30             11078        Joe
# 17436         75085       11927 2014-06-30             11927  Elizabeth
# 17437         75087       11794 2014-06-30             11794   Victoria
#
#        LastName
# 17463   Johnson
# 17449    Wright
# 17435      Sanz
# 17436  Martinez
# 17437  Williams

# %%
# 254 Retrieve the top 10 customers with the highest total order amounts along with their corresponding order details.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
soh.groupby(['CustomerID', 'SalesOrderID'])['TotalDue'].sum().reset_index().sort_values('TotalDue', ascending=False).head()
# Out:
#        CustomerID  SalesOrderID     TotalDue
# 28640       29641         51131  187487.8250
# 28641       29641         55282  182018.6272
# 28464       29614         46616  170512.6689
# 31349       30103         46981  166537.0808
# 29005       29701         47395  165028.7482

# %%
# 255 Retrieve the list of employees along with the total number of orders each employee has processed, only for employees with more than 10 orders.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
soh.groupby(['SalesPersonID'])['SalesOrderID'].count().reset_index().query('SalesOrderID > 10').head()
# Out:
#    SalesPersonID  SalesOrderID
# 0          274.0            48
# 1          275.0           450
# 2          276.0           418
# 3          277.0           473
# 4          278.0           234

# %%
# 256 Retrieve the total sales amount for each product category, joining the SalesOrderDetail table with the Product and ProductCategory tables.

sod = db_reader().read_table('sales.salesorderdetail', connection)
sod.head()
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43660                  13          6431-4D57-83         1
# 1         43660                  14          6431-4D57-83         1
# 2         43661                  15          4E0A-4F89-AE         1
# 3         43661                  16          4E0A-4F89-AE         1
# 4         43661                  17          4E0A-4F89-AE         2
#
#    ProductID  SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0        762               1   419.4589                0.0   419.4589
# 1        758               1   874.7940                0.0   874.7940
# 2        745               1   809.7600                0.0   809.7600
# 3        743               1   714.7043                0.0   714.7043
# 4        747               1   714.7043                0.0  1429.4086
#
#                                 rowguid ModifiedDate
# 0  419A1302-AC7A-4044-97B2-66D9D14CD02E   2011-05-31
# ...

# %%
p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
s = merge().merge_tbl(sod[['ProductID', 'LineTotal']], p[['ProductID', 'ProductSubcategoryID']], 'inner','ProductID')
s.head()
# Out:
#    ProductID  LineTotal  ProductSubcategoryID
# 0        762   419.4589                   2.0
# 1        758   874.7940                   2.0
# 2        745   809.7600                  12.0
# 3        743   714.7043                  12.0
# 4        747  1429.4086                  12.0

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
sc = merge().merge_tbl(s[['ProductID', 'ProductSubcategoryID','LineTotal']], psc[['ProductSubcategoryID', 'ProductCategoryID']], 'inner','ProductSubcategoryID')
sc.head()
# Out:
#    ProductID  ProductSubcategoryID  LineTotal  ProductCategoryID
# 0        762                   2.0   419.4589                  1
# 1        758                   2.0   874.7940                  1
# 2        745                  12.0   809.7600                  2
# 3        743                  12.0   714.7043                  2
# 4        747                  12.0  1429.4086                  2

# %%
pc = db_reader().read_table('production.productcategory', connection)
pc.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
cat = merge().merge_tbl(sc[['ProductCategoryID', 'LineTotal']], pc[['ProductCategoryID']], 'inner', 'ProductCategoryID')
cat.head()
# Out:
#    ProductCategoryID  LineTotal
# 0                  1   419.4589
# 1                  1   874.7940
# 2                  2   809.7600
# 3                  2   714.7043
# 4                  2  1429.4086

# %%
cat.groupby('ProductCategoryID')['LineTotal'].sum().reset_index()
# Out:
#    ProductCategoryID     LineTotal
# 0                  1  9.463085e+07
# 1                  2  1.180259e+07
# 2                  3  2.120383e+06
# 3                  4  1.271992e+06

# %%
# 257 Get the list of employees along with their corresponding departments, including only employees who are currently active (based on a specified column in the Employee table).
 
col = ['BusinessEntityID',
    'NationalIDNumber',
    'LoginID',
    'OrganizationLevel',
    'JobTitle',
    'BirthDate',
    'MaritalStatus',
    'Gender',
    'HireDate',
    'SalariedFlag',
    'VacationHours',
    'SickLeaveHours',
    'CurrentFlag',
    'rowguid',
    'ModifiedDate']

# %%
emp = db_reader().read_table('humanresources.employee',connection,col)
emp.head()
# Out:
#    BusinessEntityID NationalIDNumber                   LoginID  \
# 0                 1        295847284      adventure-works\ken0
# 1                 2        245797967    adventure-works\terri0
# 2                 3        509647174  adventure-works\roberto0
# 3                 4        112457891      adventure-works\rob0
# 4                 5        695256908     adventure-works\gail0
#
#    OrganizationLevel                       JobTitle   BirthDate MaritalStatus  \
# 0                NaN        Chief Executive Officer  1969-01-29             S
# 1                1.0  Vice President of Engineering  1971-08-01             S
# 2                2.0            Engineering Manager  1974-11-12             M
# 3                3.0           Senior Tool Designer  1974-12-23             S
# 4                3.0                Design Engineer  1952-09-27             M
#
#   Gender    HireDate  SalariedFlag  VacationHours  SickLeaveHours  \
# ...

# %%
edh = db_reader().read_table('HumanResources.EmployeeDepartmentHistory',connection)
edh.head()
# Out:
#    BusinessEntityID  DepartmentID  ShiftID   StartDate     EndDate  \
# 0                 1            16        1  2009-01-14        None
# 1                 2             1        1  2008-01-31        None
# 2                 3             1        1  2007-11-11        None
# 3                 4             1        1  2007-12-05  2010-05-30
# 4                 4             2        1  2010-05-31        None
#
#   ModifiedDate
# 0   2009-01-13
# 1   2008-01-30
# 2   2007-11-10
# 3   2010-05-28
# 4   2010-05-30

# %%
dept = merge().merge_tbl(emp[['BusinessEntityID', 'CurrentFlag']], edh[['BusinessEntityID', 'DepartmentID']], 'inner', 'BusinessEntityID')
dept.head()
# Out:
#    BusinessEntityID  CurrentFlag  DepartmentID
# 0                 1         True            16
# 1                 2         True             1
# 2                 3         True             1
# 3                 4         True             1
# 4                 4         True             2

# %%
d = db_reader().read_table('HumanResources.Department',connection)
d.head()
# Out:
#    DepartmentID         Name                 GroupName ModifiedDate
# 0             1  Engineering  Research and Development   2008-04-30
# 1             2  Tool Design  Research and Development   2008-04-30
# 2             3        Sales       Sales and Marketing   2008-04-30
# 3             4    Marketing       Sales and Marketing   2008-04-30
# 4             5   Purchasing      Inventory Management   2008-04-30

# %%
e = merge().merge_tbl(dept ,d[['DepartmentID', 'Name']], 'inner', 'DepartmentID')
e.head()
# Out:
#    BusinessEntityID  CurrentFlag  DepartmentID         Name
# 0                 1         True            16    Executive
# 1                 2         True             1  Engineering
# 2                 3         True             1  Engineering
# 3                 4         True             1  Engineering
# 4                 4         True             2  Tool Design

# %%
e[e['CurrentFlag'] == True].head()
# Out:
#    BusinessEntityID  CurrentFlag  DepartmentID         Name
# 0                 1         True            16    Executive
# 1                 2         True             1  Engineering
# 2                 3         True             1  Engineering
# 3                 4         True             1  Engineering
# 4                 4         True             2  Tool Design

# %%
# 258 Retrieve the list of product categories along with the number of products in each category, including categories without any products, by joining the ProductCategory table with the Product table.

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
cat = merge().merge_tbl(p[['ProductID','ProductSubcategoryID']], psc[['ProductSubcategoryID', 'ProductCategoryID']], 'outer', 'ProductSubcategoryID')
cat.head()
# Out:
#    ProductID  ProductSubcategoryID  ProductCategoryID
# 0      771.0                   1.0                1.0
# 1      772.0                   1.0                1.0
# 2      773.0                   1.0                1.0
# 3      774.0                   1.0                1.0
# 4      775.0                   1.0                1.0

# %%
cat.groupby('ProductCategoryID')['ProductID'].count().reset_index()
# Out:
#    ProductCategoryID  ProductID
# 0                1.0         97
# 1                2.0        134
# 2                3.0         36
# 3                4.0         29

# %%
# 259 Retrieve a list of customers and orders, including customers who haven't placed any orders and orders without associated customers. Additionally, display "No Order" for customers who haven't placed any orders.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
cus = db_reader().read_table('sales.customer', connection)
cus.head()
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           2       NaN   1028.0            1    AW00000002
# 1           3       NaN    642.0            4    AW00000003
# 2           4       NaN    932.0            4    AW00000004
# 3           5       NaN   1026.0            4    AW00000005
# 4           6       NaN    644.0            4    AW00000006
#
#                                 rowguid            ModifiedDate
# 0  E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 1  130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 2  FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 3  83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 4  1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263

# %%
cust = merge().merge_tbl(soh[['SalesOrderID','CustomerID']], cus['PersonID'], 'outer', col1 = 'CustomerID', col2 = 'PersonID')
cust.head()
# Out:
#    SalesOrderID  CustomerID  PersonID
# 0           NaN         NaN     291.0
# 1           NaN         NaN     293.0
# 2           NaN         NaN     295.0
# 3           NaN         NaN     297.0
# 4           NaN         NaN     299.0

# %%
cust['SalesOrderID'] = cust['SalesOrderID'].fillna('No Order')

# %%
cust.head()
# Out:
#   SalesOrderID  CustomerID  PersonID
# 0     No Order         NaN     291.0
# 1     No Order         NaN     293.0
# 2     No Order         NaN     295.0
# 3     No Order         NaN     297.0
# 4     No Order         NaN     299.0

# %%
# 260 Generate a Cartesian product of product categories and territories, showing all possible combinations, but filter the result to include only territories located in a specific country.

cat = db_reader().read_table('production.productcategory', connection)
cat.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
t = db_reader().read_table('sales.salesterritory', connection)
t.head()
# Out:
#    TerritoryID       Name CountryRegionCode          Group      SalesYTD  \
# 0            1  Northwest                US  North America  7.887187e+06
# 1            2  Northeast                US  North America  2.402177e+06
# 2            3    Central                US  North America  3.072175e+06
# 3            4  Southwest                US  North America  1.051085e+07
# 4            5  Southeast                US  North America  2.538667e+06
#
#    SalesLastYear  CostYTD  CostLastYear                               rowguid  \
# 0   3.298694e+06      0.0           0.0  43689A10-E30B-497F-B0DE-11DE20267FF7
# 1   3.607149e+06      0.0           0.0  00FB7309-96CC-49E2-8363-0A1BA72486F2
# 2   3.205014e+06      0.0           0.0  DF6E7FD8-1A8D-468C-B103-ED8ADDB452C1
# 3   5.366576e+06      0.0           0.0  DC3E9EA0-7950-4431-9428-99DBCBC33865
# 4   3.925071e+06      0.0           0.0  6DC4165A-5E4C-42D2-809D-4344E0AC75E7
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# ...

# %%
cart = pd.merge(cat[['ProductCategoryID']],t[['TerritoryID']], how='cross')
cart.head()
# Out:
#    ProductCategoryID  TerritoryID
# 0                  1            1
# 1                  1            2
# 2                  1            3
# 3                  1            4
# 4                  1            5

# %%
# 261 Retrieve the names of employees along with the names of their managers, including multiple levels of hierarchy if applicable.

# %%
# 262 Retrieve the list of orders along with the names of customers who placed those orders and the names of the sales representatives who handled those orders, joining the SalesOrderHeader table with the Customer and SalesPerson tables.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
per = db_reader().read_table('person.person', connection)
per.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM      False  None       Ken          J
# 1                 2         EM      False  None     Terri        Lee
# 2                 3         EM      False  None   Roberto       None
# 3                 4         EM      False  None       Rob       None
# 4                 5         EM      False   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion AdditionalContactInfo  \
# 0     Sánchez   None               0                  None
# 1       Duffy   None               1                  None
# 2  Tamburello   None               0                  None
# 3     Walters   None               0                  None
# 4    Erickson   None               0                  None
#
#                                         Demographics  \
# 0  <IndividualSurvey xmlns="http://schemas.micros...
# 1  <IndividualSurvey xmlns="http://schemas.micros...
# ...

# %%
c = db_reader().read_table('sales.customer', connection)
c.head()
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           2       NaN   1028.0            1    AW00000002
# 1           3       NaN    642.0            4    AW00000003
# 2           4       NaN    932.0            4    AW00000004
# 3           5       NaN   1026.0            4    AW00000005
# 4           6       NaN    644.0            4    AW00000006
#
#                                 rowguid            ModifiedDate
# 0  E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 1  130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 2  FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 3  83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 4  1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263

# %%
sal = merge().merge_tbl(soh[['SalesOrderID' ,'SalesPersonID', 'CustomerID']], per[['BusinessEntityID', 'FirstName', 'LastName']], 'inner', col1 = 'SalesPersonID', col2 = 'BusinessEntityID')
sal.head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID  BusinessEntityID FirstName  \
# 0         43660          279.0       29672               279      Tsvi
# 1         43661          282.0       29734               282      José
# 2         43662          282.0       29994               282      José
# 3         43663          276.0       29565               276     Linda
# 4         43664          280.0       29898               280    Pamela
#
#        LastName
# 0        Reiter
# 1       Saraiva
# 2       Saraiva
# 3      Mitchell
# 4  Ansman-Wolfe

# %%
sale = merge().merge_tbl(sal, c[['CustomerID', 'PersonID']], 'inner', 'CustomerID')
sale.head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID  BusinessEntityID FirstName  \
# 0         43660          279.0       29672               279      Tsvi
# 1         43661          282.0       29734               282      José
# 2         43662          282.0       29994               282      José
# 3         43663          276.0       29565               276     Linda
# 4         43664          280.0       29898               280    Pamela
#
#        LastName  PersonID
# 0        Reiter     721.0
# 1       Saraiva     851.0
# 2       Saraiva    1417.0
# 3      Mitchell     483.0
# 4  Ansman-Wolfe    1205.0

# %%
customer = merge().merge_tbl(sale, per[['BusinessEntityID', 'FirstName', 'LastName']], 'inner', col1 = 'PersonID', col2 = 'BusinessEntityID').rename(columns = {'BusinessEntityID_x' : 's_id', 'FirstName_x' : 's_f_name', 'LastName_x' : 's_l_name','BusinessEntityID_y' : 'c_id', 'FirstName_y' : 'c_f_name', 'LastName_y' : 'c_l_name'})
customer.head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID  s_id s_f_name      s_l_name  \
# 0         43660          279.0       29672   279     Tsvi        Reiter
# 1         43661          282.0       29734   282     José       Saraiva
# 2         43662          282.0       29994   282     José       Saraiva
# 3         43663          276.0       29565   276    Linda      Mitchell
# 4         43664          280.0       29898   280   Pamela  Ansman-Wolfe
#
#    PersonID  c_id c_f_name  c_l_name
# 0     721.0   721   Takiko   Collins
# 1     851.0   851    Jauna     Elson
# 2    1417.0  1417    Robin  McGuigan
# 3     483.0   483    Jimmy  Bischoff
# 4    1205.0  1205  Sandeep    Katyal

# %%
# 263 Retrieve the list of employees who have sold products with a total sales amount exceeding the average sales amount of all employees, joining the Employee and SalesOrderHeader tables.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
soh.groupby('SalesPersonID')['TotalDue'].sum().rename('Total').reset_index().query('Total > @soh["TotalDue"].mean()').head()
# Out:
#    SalesPersonID         Total
# 0          274.0  1.235934e+06
# 1          275.0  1.047537e+07
# 2          276.0  1.169502e+07
# 3          277.0  1.134239e+07
# 4          278.0  4.069422e+06

# %%
# 264 Retrieve the list of customers along with the total number of orders they've placed and the total amount spent by each customer, only including customers who have placed more than 5 orders and spent more than $1000 in total.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
soh.groupby('CustomerID').agg({'SalesOrderID' : 'count', 'TotalDue' : 'sum'}).rename(columns = {'SalesOrderID' : 'number', 'TotalDue' : 'total'}).reset_index().query('number > 5 and total > 1000').head()
# Out:
#      CustomerID  number      total
# 78        11078      17  1009.1637
# 91        11091      28  1314.2103
# 142       11142      17  1083.7513
# 176       11176      28  1458.6118
# 185       11185      27  1786.0233

# %%
# 265 Retrieve the list of employees along with their first and last names from both the Employee and EmployeeBackup tables, combining the results using UNION, and then filtering out duplicate records.

col = ['BusinessEntityID',
    'NationalIDNumber',
    'LoginID',
    'OrganizationLevel',
    'JobTitle',
    'BirthDate',
    'MaritalStatus',
    'Gender',
    'HireDate',
    'SalariedFlag',
    'VacationHours',
    'SickLeaveHours',
    'CurrentFlag',
    'rowguid',
    'ModifiedDate']

# %%
emp = db_reader().read_table('humanresources.employee',connection,col)
emp.head()
# Out:
#    BusinessEntityID NationalIDNumber                   LoginID  \
# 0                 1        295847284      adventure-works\ken0
# 1                 2        245797967    adventure-works\terri0
# 2                 3        509647174  adventure-works\roberto0
# 3                 4        112457891      adventure-works\rob0
# 4                 5        695256908     adventure-works\gail0
#
#    OrganizationLevel                       JobTitle   BirthDate MaritalStatus  \
# 0                NaN        Chief Executive Officer  1969-01-29             S
# 1                1.0  Vice President of Engineering  1971-08-01             S
# 2                2.0            Engineering Manager  1974-11-12             M
# 3                3.0           Senior Tool Designer  1974-12-23             S
# 4                3.0                Design Engineer  1952-09-27             M
#
#   Gender    HireDate  SalariedFlag  VacationHours  SickLeaveHours  \
# ...

# %%
name = db_reader().read_table('person.person',connection)
name.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM      False  None       Ken          J
# 1                 2         EM      False  None     Terri        Lee
# 2                 3         EM      False  None   Roberto       None
# 3                 4         EM      False  None       Rob       None
# 4                 5         EM      False   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion AdditionalContactInfo  \
# 0     Sánchez   None               0                  None
# 1       Duffy   None               1                  None
# 2  Tamburello   None               0                  None
# 3     Walters   None               0                  None
# 4    Erickson   None               0                  None
#
#                                         Demographics  \
# 0  <IndividualSurvey xmlns="http://schemas.micros...
# 1  <IndividualSurvey xmlns="http://schemas.micros...
# ...

# %%
e_name = merge().merge_tbl(emp[['BusinessEntityID']], name[['BusinessEntityID', 'FirstName', 'LastName']], 'inner',  'BusinessEntityID')
e_name.head()
# Out:
#    BusinessEntityID FirstName    LastName
# 0                 1       Ken     Sánchez
# 1                 2     Terri       Duffy
# 2                 3   Roberto  Tamburello
# 3                 4       Rob     Walters
# 4                 5      Gail    Erickson

# %%
# 266 Retrieve the list of products along with their product subcategory names and product category names by joining the Product, ProductSubcategory, and ProductCategory tables.

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
sc = merge().merge_tbl(s[['ProductID', 'ProductSubcategoryID']], psc[['ProductSubcategoryID', 'Name','ProductCategoryID']], 'inner','ProductSubcategoryID')
sc.head()
# Out:
#    ProductID  ProductSubcategoryID             Name  ProductCategoryID
# 0        762                   2.0       Road Bikes                  1
# 1        758                   2.0       Road Bikes                  1
# 2        745                  12.0  Mountain Frames                  2
# 3        743                  12.0  Mountain Frames                  2
# 4        747                  12.0  Mountain Frames                  2

# %%
pc = db_reader().read_table('production.productcategory', connection)
pc.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
cat = merge().merge_tbl(pc[['ProductCategoryID','Name']], sc[['ProductSubcategoryID', 'Name','ProductCategoryID']], 'inner', 'ProductCategoryID')
cat.head()
# Out:
#    ProductCategoryID Name_x  ProductSubcategoryID          Name_y
# 0                  1  Bikes                   2.0      Road Bikes
# 1                  1  Bikes                   2.0      Road Bikes
# 2                  1  Bikes                   1.0  Mountain Bikes
# 3                  1  Bikes                   1.0  Mountain Bikes
# 4                  1  Bikes                   1.0  Mountain Bikes

# %%
# 267 Get the list of employees along with their hire date and the number of years they've been with the company, including employees who are not assigned to any department.

col = ['BusinessEntityID',
    'NationalIDNumber',
    'LoginID',
    'OrganizationLevel',
    'JobTitle',
    'BirthDate',
    'MaritalStatus',
    'Gender',
    'HireDate',
    'SalariedFlag',
    'VacationHours',
    'SickLeaveHours',
    'CurrentFlag',
    'rowguid',
    'ModifiedDate']

# %%
emp = db_reader().read_table('humanresources.employee',connection,col)
emp.head()
# Out:
#    BusinessEntityID NationalIDNumber                   LoginID  \
# 0                 1        295847284      adventure-works\ken0
# 1                 2        245797967    adventure-works\terri0
# 2                 3        509647174  adventure-works\roberto0
# 3                 4        112457891      adventure-works\rob0
# 4                 5        695256908     adventure-works\gail0
#
#    OrganizationLevel                       JobTitle   BirthDate MaritalStatus  \
# 0                NaN        Chief Executive Officer  1969-01-29             S
# 1                1.0  Vice President of Engineering  1971-08-01             S
# 2                2.0            Engineering Manager  1974-11-12             M
# 3                3.0           Senior Tool Designer  1974-12-23             S
# 4                3.0                Design Engineer  1952-09-27             M
#
#   Gender    HireDate  SalariedFlag  VacationHours  SickLeaveHours  \
# ...

# %%
emp['No Of Years'] = pd.Timestamp.now().year - pd.to_datetime(emp['HireDate']).dt.year

# %%
emp[['BusinessEntityID', 'HireDate', 'No Of Years']].head()
# Out:
#    BusinessEntityID    HireDate  No Of Years
# 0                 1  2009-01-14           15
# 1                 2  2008-01-31           16
# 2                 3  2007-11-11           17
# 3                 4  2007-12-05           17
# 4                 5  2008-01-06           16

# %%
# 268 Retrieve the list of product categories along with the names of products belonging to each category, including only categories with at least one product with a list price greater than $500.

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
cat = merge().merge_tbl(p[['ProductID', 'Name','ProductSubcategoryID', 'ListPrice']], psc[['ProductSubcategoryID', 'ProductCategoryID']], 'outer', 'ProductSubcategoryID')
cat.head()
# Out:
#    ProductID                     Name  ProductSubcategoryID  ListPrice  \
# 0      771.0  Mountain-100 Silver, 38                   1.0    146.674
# 1      772.0  Mountain-100 Silver, 42                   1.0    146.674
# 2      773.0  Mountain-100 Silver, 44                   1.0    146.674
# 3      774.0  Mountain-100 Silver, 48                   1.0    146.674
# 4      775.0   Mountain-100 Black, 38                   1.0    146.674
#
#    ProductCategoryID
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0

# %%
c = db_reader().read_table('production.productcategory', connection)
c.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
pc = merge().merge_tbl(cat, c[['ProductCategoryID', 'Name']], 'inner', 'ProductCategoryID')
pc.head()
# Out:
#    ProductID                   Name_x  ProductSubcategoryID  ListPrice  \
# 0      771.0  Mountain-100 Silver, 38                   1.0    146.674
# 1      772.0  Mountain-100 Silver, 42                   1.0    146.674
# 2      773.0  Mountain-100 Silver, 44                   1.0    146.674
# 3      774.0  Mountain-100 Silver, 48                   1.0    146.674
# 4      775.0   Mountain-100 Black, 38                   1.0    146.674
#
#    ProductCategoryID Name_y
# 0                1.0  Bikes
# 1                1.0  Bikes
# 2                1.0  Bikes
# 3                1.0  Bikes
# 4                1.0  Bikes

# %%
pc[pc['ListPrice'] > 500].head()
# Out:
#      ProductID                          Name_x  ProductSubcategoryID  \
# 122      739.0  HL Mountain Frame - Silver, 42                  12.0
# 123      740.0  HL Mountain Frame - Silver, 44                  12.0
# 124      741.0  HL Mountain Frame - Silver, 48                  12.0
# 125      742.0  HL Mountain Frame - Silver, 46                  12.0
# 126      743.0   HL Mountain Frame - Black, 42                  12.0
#
#      ListPrice  ProductCategoryID      Name_y
# 122     1364.5                2.0  Components
# 123     1364.5                2.0  Components
# 124     1364.5                2.0  Components
# 125     1364.5                2.0  Components
# 126     1349.6                2.0  Components

# %%
# 269 Retrieve a list of customers and orders, including customers who haven't placed any orders and orders without associated customers. Additionally, display the total number of orders placed by each customer.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
cus = db_reader().read_table('sales.customer', connection)
cus.head()
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           2       NaN   1028.0            1    AW00000002
# 1           3       NaN    642.0            4    AW00000003
# 2           4       NaN    932.0            4    AW00000004
# 3           5       NaN   1026.0            4    AW00000005
# 4           6       NaN    644.0            4    AW00000006
#
#                                 rowguid            ModifiedDate
# 0  E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 1  130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 2  FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 3  83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 4  1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263

# %%
cust = merge().merge_tbl(soh[['SalesOrderID','CustomerID']], cus['PersonID'], 'left', col1 = 'CustomerID', col2 = 'PersonID')
cust.head()
# Out:
#    SalesOrderID  CustomerID  PersonID
# 0         43660       29672       NaN
# 1         43661       29734       NaN
# 2         43662       29994       NaN
# 3         43663       29565       NaN
# 4         43664       29898       NaN

# %%
cust.groupby('PersonID')['SalesOrderID'].count().rename('count').reset_index().head()
# Out:
#    PersonID  count
# 0   11000.0      3
# 1   11001.0      3
# 2   11002.0      3
# 3   11003.0      3
# 4   11004.0      3

# %%
# 270 Generate a Cartesian product of product categories and territories, showing all possible combinations, and calculate the total sales amount for each combination.

cat = db_reader().read_table('production.productcategory', connection)
cat.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
t = db_reader().read_table('sales.salesterritory', connection)
t.head()
# Out:
#    TerritoryID       Name CountryRegionCode          Group      SalesYTD  \
# 0            1  Northwest                US  North America  7.887187e+06
# 1            2  Northeast                US  North America  2.402177e+06
# 2            3    Central                US  North America  3.072175e+06
# 3            4  Southwest                US  North America  1.051085e+07
# 4            5  Southeast                US  North America  2.538667e+06
#
#    SalesLastYear  CostYTD  CostLastYear                               rowguid  \
# 0   3.298694e+06      0.0           0.0  43689A10-E30B-497F-B0DE-11DE20267FF7
# 1   3.607149e+06      0.0           0.0  00FB7309-96CC-49E2-8363-0A1BA72486F2
# 2   3.205014e+06      0.0           0.0  DF6E7FD8-1A8D-468C-B103-ED8ADDB452C1
# 3   5.366576e+06      0.0           0.0  DC3E9EA0-7950-4431-9428-99DBCBC33865
# 4   3.925071e+06      0.0           0.0  6DC4165A-5E4C-42D2-809D-4344E0AC75E7
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# ...

# %%
cart = pd.merge(cat[['ProductCategoryID']],t[['TerritoryID']], how='cross')
cart.head()
# Out:
#    ProductCategoryID  TerritoryID
# 0                  1            1
# 1                  1            2
# 2                  1            3
# 3                  1            4
# 4                  1            5

# %%
# 271 Retrieve the hierarchy of employees, including their managers and subordinates, using a recursive common table expression (CTE).

# %%
# 272 Retrieve the list of orders along with the names of customers who placed those orders and the names of the sales representatives who handled those orders, only including orders with a total due amount greater than $1000.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
per = db_reader().read_table('person.person', connection)
per.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM      False  None       Ken          J
# 1                 2         EM      False  None     Terri        Lee
# 2                 3         EM      False  None   Roberto       None
# 3                 4         EM      False  None       Rob       None
# 4                 5         EM      False   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion AdditionalContactInfo  \
# 0     Sánchez   None               0                  None
# 1       Duffy   None               1                  None
# 2  Tamburello   None               0                  None
# 3     Walters   None               0                  None
# 4    Erickson   None               0                  None
#
#                                         Demographics  \
# 0  <IndividualSurvey xmlns="http://schemas.micros...
# 1  <IndividualSurvey xmlns="http://schemas.micros...
# ...

# %%
c = db_reader().read_table('sales.customer', connection)
c.head()
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           2       NaN   1028.0            1    AW00000002
# 1           3       NaN    642.0            4    AW00000003
# 2           4       NaN    932.0            4    AW00000004
# 3           5       NaN   1026.0            4    AW00000005
# 4           6       NaN    644.0            4    AW00000006
#
#                                 rowguid            ModifiedDate
# 0  E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 1  130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 2  FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 3  83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 4  1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263

# %%
sal = merge().merge_tbl(soh[['SalesOrderID' ,'SalesPersonID', 'CustomerID', 'TotalDue']], per[['BusinessEntityID', 'FirstName', 'LastName']], 'inner', col1 = 'SalesPersonID', col2 = 'BusinessEntityID')
sal.head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID    TotalDue  BusinessEntityID  \
# 0         43660          279.0       29672   1457.3288               279
# 1         43661          282.0       29734  36865.8012               282
# 2         43662          282.0       29994  32474.9324               282
# 3         43663          276.0       29565    472.3108               276
# 4         43664          280.0       29898  27510.4109               280
#
#   FirstName      LastName
# 0      Tsvi        Reiter
# 1      José       Saraiva
# 2      José       Saraiva
# 3     Linda      Mitchell
# 4    Pamela  Ansman-Wolfe

# %%
sale = merge().merge_tbl(sal, c[['CustomerID', 'PersonID']], 'inner', 'CustomerID')
sale.head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID    TotalDue  BusinessEntityID  \
# 0         43660          279.0       29672   1457.3288               279
# 1         43661          282.0       29734  36865.8012               282
# 2         43662          282.0       29994  32474.9324               282
# 3         43663          276.0       29565    472.3108               276
# 4         43664          280.0       29898  27510.4109               280
#
#   FirstName      LastName  PersonID
# 0      Tsvi        Reiter     721.0
# 1      José       Saraiva     851.0
# 2      José       Saraiva    1417.0
# 3     Linda      Mitchell     483.0
# 4    Pamela  Ansman-Wolfe    1205.0

# %%
customer = merge().merge_tbl(sale, per[['BusinessEntityID', 'FirstName', 'LastName']], 'inner', col1 = 'PersonID', col2 = 'BusinessEntityID').rename(columns = {'BusinessEntityID_x' : 's_id', 'FirstName_x' : 's_f_name', 'LastName_x' : 's_l_name','BusinessEntityID_y' : 'c_id', 'FirstName_y' : 'c_f_name', 'LastName_y' : 'c_l_name'})
customer[customer['TotalDue'] > 1000].head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID    TotalDue  s_id s_f_name  \
# 0         43660          279.0       29672   1457.3288   279     Tsvi
# 1         43661          282.0       29734  36865.8012   282     José
# 2         43662          282.0       29994  32474.9324   282     José
# 4         43664          280.0       29898  27510.4109   280   Pamela
# 5         43665          283.0       29580  16158.6961   283    David
#
#        s_l_name  PersonID  c_id c_f_name  c_l_name
# 0        Reiter     721.0   721   Takiko   Collins
# 1       Saraiva     851.0   851    Jauna     Elson
# 2       Saraiva    1417.0  1417    Robin  McGuigan
# 4  Ansman-Wolfe    1205.0  1205  Sandeep    Katyal
# 5      Campbell     517.0   517  Richard    Bready

# %%
# 273 Retrieve the list of product categories along with the average list price of products in each category, only including categories where the average list price is higher than the overall average list price of all products.

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
sc = merge().merge_tbl(p[['ProductID', 'ProductSubcategoryID', 'ListPrice']], psc[['ProductSubcategoryID', 'Name','ProductCategoryID']], 'inner','ProductSubcategoryID')
sc.head()
# Out:
#    ProductID  ProductSubcategoryID  ListPrice         Name  ProductCategoryID
# 0        680                  14.0    1431.50  Road Frames                  2
# 1        706                  14.0    1431.50  Road Frames                  2
# 2        707                  31.0      34.99      Helmets                  4
# 3        708                  31.0      34.99      Helmets                  4
# 4        709                  23.0       9.50        Socks                  3

# %%
pc = db_reader().read_table('production.productcategory', connection)
pc.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
cat = merge().merge_tbl(pc[['ProductCategoryID','Name']], sc[['ProductSubcategoryID','ProductCategoryID', 'ProductID','ListPrice']], 'inner', 'ProductCategoryID')
cat.head()
# Out:
#    ProductCategoryID   Name  ProductSubcategoryID  ProductID  ListPrice
# 0                  1  Bikes                   2.0        749    146.674
# 1                  1  Bikes                   2.0        750    146.674
# 2                  1  Bikes                   2.0        751    146.674
# 3                  1  Bikes                   2.0        752    146.674
# 4                  1  Bikes                   2.0        753    146.674

# %%
overall = cat['ListPrice'].mean()
overall
# Out:
# 270.19722297297295

# %%
cat.groupby(['ProductCategoryID', 'ProductID'])['ListPrice'].mean().reset_index().query('ListPrice > @overall').head()
# Out:
#      ProductCategoryID  ProductID  ListPrice
# 97                   2        680     1431.5
# 98                   2        706     1431.5
# 99                   2        717     1431.5
# 100                  2        718     1431.5
# 101                  2        719     1431.5

# %%
# 274 Retrieve the list of employees along with their departments and the total number of orders they've processed, only including employees who have processed more than 50 orders and belong to a department with at least 5 employees.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
d = db_reader().read_table('humanresources.department', connection)
d.head()
# Out:
#    DepartmentID         Name                 GroupName ModifiedDate
# 0             1  Engineering  Research and Development   2008-04-30
# 1             2  Tool Design  Research and Development   2008-04-30
# 2             3        Sales       Sales and Marketing   2008-04-30
# 3             4    Marketing       Sales and Marketing   2008-04-30
# 4             5   Purchasing      Inventory Management   2008-04-30

# %%
edh = db_reader().read_table('humanresources.employeedepartmenthistory', connection)
edh.head()
# Out:
#    BusinessEntityID  DepartmentID  ShiftID   StartDate     EndDate  \
# 0                 1            16        1  2009-01-14        None
# 1                 2             1        1  2008-01-31        None
# 2                 3             1        1  2007-11-11        None
# 3                 4             1        1  2007-12-05  2010-05-30
# 4                 4             2        1  2010-05-31        None
#
#   ModifiedDate
# 0   2009-01-13
# 1   2008-01-30
# 2   2007-11-10
# 3   2010-05-28
# 4   2010-05-30

# %%
per = merge().merge_tbl(soh[['SalesOrderID', 'SalesPersonID']], edh[['BusinessEntityID', 'DepartmentID']], 'inner', col1 = 'SalesPersonID', col2 = 'BusinessEntityID')
per.head()
# Out:
#    SalesOrderID  SalesPersonID  BusinessEntityID  DepartmentID
# 0         43660          279.0               279             3
# 1         43661          282.0               282             3
# 2         43662          282.0               282             3
# 3         43663          276.0               276             3
# 4         43664          280.0               280             3

# %%
dept = merge().merge_tbl(per, d[['DepartmentID', 'Name']], 'inner', 'DepartmentID')
dept.head()
# Out:
#    SalesOrderID  SalesPersonID  BusinessEntityID  DepartmentID   Name
# 0         43660          279.0               279             3  Sales
# 1         43661          282.0               282             3  Sales
# 2         43662          282.0               282             3  Sales
# 3         43663          276.0               276             3  Sales
# 4         43664          280.0               280             3  Sales

# %%
dept.groupby(['DepartmentID', 'BusinessEntityID']).agg({'SalesOrderID' : 'count'}).rename(columns = {'SalesOrderID' : 'count_of_o'}).reset_index().query('count_of_o > 50').head()
# Out:
#    DepartmentID  BusinessEntityID  count_of_o
# 1             3               275         450
# 2             3               276         418
# 3             3               277         473
# 4             3               278         234
# 5             3               279         428

# %%
# 275 Retrieve the list of customers who have placed orders along with the list of customers who have not placed orders, combining the results using UNION or UNION ALL to display all customers

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
cus = db_reader().read_table('sales.customer', connection)
cus.head()
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           2       NaN   1028.0            1    AW00000002
# 1           3       NaN    642.0            4    AW00000003
# 2           4       NaN    932.0            4    AW00000004
# 3           5       NaN   1026.0            4    AW00000005
# 4           6       NaN    644.0            4    AW00000006
#
#                                 rowguid            ModifiedDate
# 0  E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 1  130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 2  FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 3  83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 4  1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263

# %%
new = pd.concat([cus['CustomerID'], soh['CustomerID']])

# %%
new.head()
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# Name: CustomerID, dtype: int64

# %%
# 276 Retrieve the list of products along with their product subcategory names and product category names, only including products with a list price greater than $1000.

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
sc = merge().merge_tbl(p[['ProductID', 'ProductSubcategoryID', 'ListPrice']], psc[['ProductSubcategoryID', 'Name','ProductCategoryID']], 'inner','ProductSubcategoryID')
sc.head()
# Out:
#    ProductID  ProductSubcategoryID  ListPrice         Name  ProductCategoryID
# 0        680                  14.0    1431.50  Road Frames                  2
# 1        706                  14.0    1431.50  Road Frames                  2
# 2        707                  31.0      34.99      Helmets                  4
# 3        708                  31.0      34.99      Helmets                  4
# 4        709                  23.0       9.50        Socks                  3

# %%
pc = db_reader().read_table('production.productcategory', connection)
pc.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
cat = merge().merge_tbl(pc[['ProductCategoryID','Name']], sc[['ProductSubcategoryID','ProductCategoryID', 'ProductID','ListPrice', 'Name']], 'inner', 'ProductCategoryID')
cat.head()
# Out:
#    ProductCategoryID Name_x  ProductSubcategoryID  ProductID  ListPrice  \
# 0                  1  Bikes                   2.0        749    146.674
# 1                  1  Bikes                   2.0        750    146.674
# 2                  1  Bikes                   2.0        751    146.674
# 3                  1  Bikes                   2.0        752    146.674
# 4                  1  Bikes                   2.0        753    146.674
#
#        Name_y
# 0  Road Bikes
# 1  Road Bikes
# 2  Road Bikes
# 3  Road Bikes
# 4  Road Bikes

# %%
cat[cat['ListPrice'] > 1000].head()
# Out:
#      ProductCategoryID      Name_x  ProductSubcategoryID  ProductID  \
# 97                   2  Components                  14.0        680
# 98                   2  Components                  14.0        706
# 99                   2  Components                  14.0        717
# 100                  2  Components                  14.0        718
# 101                  2  Components                  14.0        719
#
#      ListPrice       Name_y
# 97      1431.5  Road Frames
# 98      1431.5  Road Frames
# 99      1431.5  Road Frames
# 100     1431.5  Road Frames
# 101     1431.5  Road Frames

# %%
# 277 Get the list of employees along with their departments and the total number of employees in each department, including departments with no employees

d = db_reader().read_table('humanresources.department', connection)
d.head()
# Out:
#    DepartmentID         Name                 GroupName ModifiedDate
# 0             1  Engineering  Research and Development   2008-04-30
# 1             2  Tool Design  Research and Development   2008-04-30
# 2             3        Sales       Sales and Marketing   2008-04-30
# 3             4    Marketing       Sales and Marketing   2008-04-30
# 4             5   Purchasing      Inventory Management   2008-04-30

# %%
edh = db_reader().read_table('humanresources.employeedepartmenthistory', connection)
edh.head()
# Out:
#    BusinessEntityID  DepartmentID  ShiftID   StartDate     EndDate  \
# 0                 1            16        1  2009-01-14        None
# 1                 2             1        1  2008-01-31        None
# 2                 3             1        1  2007-11-11        None
# 3                 4             1        1  2007-12-05  2010-05-30
# 4                 4             2        1  2010-05-31        None
#
#   ModifiedDate
# 0   2009-01-13
# 1   2008-01-30
# 2   2007-11-10
# 3   2010-05-28
# 4   2010-05-30

# %%
per = merge().merge_tbl(d[['DepartmentID', 'Name']], edh[['BusinessEntityID', 'DepartmentID']], 'inner', 'DepartmentID')
per.head()
# Out:
#    DepartmentID         Name  BusinessEntityID
# 0             1  Engineering                 2
# 1             1  Engineering                 3
# 2             1  Engineering                 4
# 3             1  Engineering                 5
# 4             1  Engineering                 6

# %%
per.groupby('Name')['BusinessEntityID'].count().reset_index().head()
# Out:
#                          Name  BusinessEntityID
# 0            Document Control                 5
# 1                 Engineering                 7
# 2                   Executive                 2
# 3  Facilities and Maintenance                 7
# 4                     Finance                11

# %%
# 278 Retrieve the list of product categories along with the total number of products in each category and the average list price, including categories without any products.

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
sc = merge().merge_tbl(p[['ProductID', 'ProductSubcategoryID', 'ListPrice']], psc[['ProductSubcategoryID','ProductCategoryID']], 'outer','ProductSubcategoryID')
sc.head()
# Out:
#    ProductID  ProductSubcategoryID  ListPrice  ProductCategoryID
# 0      771.0                   1.0    146.674                1.0
# 1      772.0                   1.0    146.674                1.0
# 2      773.0                   1.0    146.674                1.0
# 3      774.0                   1.0    146.674                1.0
# 4      775.0                   1.0    146.674                1.0

# %%
pc = db_reader().read_table('production.productcategory', connection)
pc.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
cat = merge().merge_tbl(pc[['ProductCategoryID','Name']], sc[['ProductSubcategoryID','ProductCategoryID', 'ProductID','ListPrice']], 'outer', 'ProductCategoryID')
cat.head()
# Out:
#    ProductCategoryID   Name  ProductSubcategoryID  ProductID  ListPrice
# 0                1.0  Bikes                   1.0      771.0    146.674
# 1                1.0  Bikes                   1.0      772.0    146.674
# 2                1.0  Bikes                   1.0      773.0    146.674
# 3                1.0  Bikes                   1.0      774.0    146.674
# 4                1.0  Bikes                   1.0      775.0    146.674

# %%
cat.groupby('ProductCategoryID').agg({'ProductID' : 'count', 'ListPrice' : 'mean'}).reset_index().head()
# Out:
#    ProductCategoryID  ProductID   ListPrice
# 0                1.0         97  146.674000
# 1                2.0        134  469.860299
# 2                3.0         36   49.822222
# 3                4.0         29   34.348966

# %%
# 279 Retrieve a list of customers and orders, including customers who haven't placed any orders and orders without associated customers. Additionally, display the total number of orders placed by each customer, excluding customers with no orders.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
cus = db_reader().read_table('sales.customer', connection)
cus.head()
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           2       NaN   1028.0            1    AW00000002
# 1           3       NaN    642.0            4    AW00000003
# 2           4       NaN    932.0            4    AW00000004
# 3           5       NaN   1026.0            4    AW00000005
# 4           6       NaN    644.0            4    AW00000006
#
#                                 rowguid            ModifiedDate
# 0  E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 1  130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 2  FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 3  83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 4  1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263

# %%
s_c = merge().merge_tbl(soh[['SalesOrderID','CustomerID']], cus[['CustomerID']], 'outer', 'CustomerID')
s_c.head()
# Out:
#    SalesOrderID  CustomerID
# 0           NaN           2
# 1           NaN           3
# 2           NaN           4
# 3           NaN           5
# 4           NaN           6

# %%
s_c.groupby('CustomerID')['SalesOrderID'].count().reset_index().query('SalesOrderID > 0').head()
# Out:
#      CustomerID  SalesOrderID
# 700       11000             3
# 701       11001             3
# 702       11002             3
# 703       11003             3
# 704       11004             3

# %%
# 280 Generate a Cartesian product of product categories and territories, showing all possible combinations, and filter the result to include only territories with more than 10 customers, sorted by the total number of customers in descending order.

cat = db_reader().read_table('production.productcategory', connection)
cat.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
t = db_reader().read_table('sales.salesterritory', connection)
t.head()
# Out:
#    TerritoryID       Name CountryRegionCode          Group      SalesYTD  \
# 0            1  Northwest                US  North America  7.887187e+06
# 1            2  Northeast                US  North America  2.402177e+06
# 2            3    Central                US  North America  3.072175e+06
# 3            4  Southwest                US  North America  1.051085e+07
# 4            5  Southeast                US  North America  2.538667e+06
#
#    SalesLastYear  CostYTD  CostLastYear                               rowguid  \
# 0   3.298694e+06      0.0           0.0  43689A10-E30B-497F-B0DE-11DE20267FF7
# 1   3.607149e+06      0.0           0.0  00FB7309-96CC-49E2-8363-0A1BA72486F2
# 2   3.205014e+06      0.0           0.0  DF6E7FD8-1A8D-468C-B103-ED8ADDB452C1
# 3   5.366576e+06      0.0           0.0  DC3E9EA0-7950-4431-9428-99DBCBC33865
# 4   3.925071e+06      0.0           0.0  6DC4165A-5E4C-42D2-809D-4344E0AC75E7
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# ...

# %%
cart = pd.merge(cat[['ProductCategoryID']],t[['TerritoryID']], how='cross')
cart.head()
# Out:
#    ProductCategoryID  TerritoryID
# 0                  1            1
# 1                  1            2
# 2                  1            3
# 3                  1            4
# 4                  1            5

# %%
soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
a = merge().merge_tbl(cart, soh[['CustomerID', 'TerritoryID']], 'inner', 'TerritoryID')
a.head()
# Out:
#    ProductCategoryID  TerritoryID  CustomerID
# 0                  1            1       29898
# 1                  1            1       29580
# 2                  1            1       29747
# 3                  1            1       29890
# 4                  1            1       29497

# %%
a.groupby(['ProductCategoryID', 'TerritoryID'])['CustomerID'].count().reset_index().query('CustomerID > 10').head()
# Out:
#    ProductCategoryID  TerritoryID  CustomerID
# 0                  1            1        4594
# 1                  1            2         352
# 2                  1            3         385
# 3                  1            4        6224
# 4                  1            5         486

# %%
# 281 Retrieve the hierarchical structure of employees, including their managers and subordinates, using a recursive common table expression (CTE), and filter the result to include only employees with a hire date in the past year

# %%
# 282 Retrieve the list of orders along with the names of customers who placed those orders and the names of the sales representatives who handled those orders, only including orders with a total due amount greater than $1000 and handled by sales representatives with more than 5 years of experience.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
per = db_reader().read_table('person.person', connection)
per.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM      False  None       Ken          J
# 1                 2         EM      False  None     Terri        Lee
# 2                 3         EM      False  None   Roberto       None
# 3                 4         EM      False  None       Rob       None
# 4                 5         EM      False   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion AdditionalContactInfo  \
# 0     Sánchez   None               0                  None
# 1       Duffy   None               1                  None
# 2  Tamburello   None               0                  None
# 3     Walters   None               0                  None
# 4    Erickson   None               0                  None
#
#                                         Demographics  \
# 0  <IndividualSurvey xmlns="http://schemas.micros...
# 1  <IndividualSurvey xmlns="http://schemas.micros...
# ...

# %%
c = db_reader().read_table('sales.customer', connection)
c.head()
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           2       NaN   1028.0            1    AW00000002
# 1           3       NaN    642.0            4    AW00000003
# 2           4       NaN    932.0            4    AW00000004
# 3           5       NaN   1026.0            4    AW00000005
# 4           6       NaN    644.0            4    AW00000006
#
#                                 rowguid            ModifiedDate
# 0  E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 1  130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 2  FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 3  83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 4  1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263

# %%
sal = merge().merge_tbl(soh[['SalesOrderID' ,'SalesPersonID', 'CustomerID', 'TotalDue']], per[['BusinessEntityID', 'FirstName', 'LastName']], 'inner', col1 = 'SalesPersonID', col2 = 'BusinessEntityID')
sal.head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID    TotalDue  BusinessEntityID  \
# 0         43660          279.0       29672   1457.3288               279
# 1         43661          282.0       29734  36865.8012               282
# 2         43662          282.0       29994  32474.9324               282
# 3         43663          276.0       29565    472.3108               276
# 4         43664          280.0       29898  27510.4109               280
#
#   FirstName      LastName
# 0      Tsvi        Reiter
# 1      José       Saraiva
# 2      José       Saraiva
# 3     Linda      Mitchell
# 4    Pamela  Ansman-Wolfe

# %%
sale = merge().merge_tbl(sal, c[['CustomerID', 'PersonID']], 'inner', 'CustomerID')
sale.head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID    TotalDue  BusinessEntityID  \
# 0         43660          279.0       29672   1457.3288               279
# 1         43661          282.0       29734  36865.8012               282
# 2         43662          282.0       29994  32474.9324               282
# 3         43663          276.0       29565    472.3108               276
# 4         43664          280.0       29898  27510.4109               280
#
#   FirstName      LastName  PersonID
# 0      Tsvi        Reiter     721.0
# 1      José       Saraiva     851.0
# 2      José       Saraiva    1417.0
# 3     Linda      Mitchell     483.0
# 4    Pamela  Ansman-Wolfe    1205.0

# %%
customer = merge().merge_tbl(sale, per[['BusinessEntityID', 'FirstName', 'LastName']], 'inner', col1 = 'PersonID', col2 = 'BusinessEntityID').rename(columns = {'BusinessEntityID_x' : 's_id', 'FirstName_x' : 's_f_name', 'LastName_x' : 's_l_name','BusinessEntityID_y' : 'c_id', 'FirstName_y' : 'c_f_name', 'LastName_y' : 'c_l_name'})
a = customer[customer['TotalDue'] > 1000].head()
a
# Out:
#    SalesOrderID  SalesPersonID  CustomerID    TotalDue  s_id s_f_name  \
# 0         43660          279.0       29672   1457.3288   279     Tsvi
# 1         43661          282.0       29734  36865.8012   282     José
# 2         43662          282.0       29994  32474.9324   282     José
# 4         43664          280.0       29898  27510.4109   280   Pamela
# 5         43665          283.0       29580  16158.6961   283    David
#
#        s_l_name  PersonID  c_id c_f_name  c_l_name
# 0        Reiter     721.0   721   Takiko   Collins
# 1       Saraiva     851.0   851    Jauna     Elson
# 2       Saraiva    1417.0  1417    Robin  McGuigan
# 4  Ansman-Wolfe    1205.0  1205  Sandeep    Katyal
# 5      Campbell     517.0   517  Richard    Bready

# %%
col = ['BusinessEntityID',
    'NationalIDNumber',
    'LoginID',
    'OrganizationLevel',
    'JobTitle',
    'BirthDate',
    'MaritalStatus',
    'Gender',
    'HireDate',
    'SalariedFlag',
    'VacationHours',
    'SickLeaveHours',
    'CurrentFlag',
    'rowguid',
    'ModifiedDate']

# %%
emp = db_reader().read_table('humanresources.employee',connection,col)
emp.head()
# Out:
#    BusinessEntityID NationalIDNumber                   LoginID  \
# 0                 1        295847284      adventure-works\ken0
# 1                 2        245797967    adventure-works\terri0
# 2                 3        509647174  adventure-works\roberto0
# 3                 4        112457891      adventure-works\rob0
# 4                 5        695256908     adventure-works\gail0
#
#    OrganizationLevel                       JobTitle   BirthDate MaritalStatus  \
# 0                NaN        Chief Executive Officer  1969-01-29             S
# 1                1.0  Vice President of Engineering  1971-08-01             S
# 2                2.0            Engineering Manager  1974-11-12             M
# 3                3.0           Senior Tool Designer  1974-12-23             S
# 4                3.0                Design Engineer  1952-09-27             M
#
#   Gender    HireDate  SalariedFlag  VacationHours  SickLeaveHours  \
# ...

# %%
name = merge().merge_tbl(a, emp[['BusinessEntityID', 'HireDate']], 'inner', col1 = 'SalesPersonID',col2 = 'BusinessEntityID')
name.head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID    TotalDue  s_id s_f_name  \
# 0         43660          279.0       29672   1457.3288   279     Tsvi
# 1         43661          282.0       29734  36865.8012   282     José
# 2         43662          282.0       29994  32474.9324   282     José
# 3         43664          280.0       29898  27510.4109   280   Pamela
# 4         43665          283.0       29580  16158.6961   283    David
#
#        s_l_name  PersonID  c_id c_f_name  c_l_name  BusinessEntityID  \
# 0        Reiter     721.0   721   Takiko   Collins               279
# 1       Saraiva     851.0   851    Jauna     Elson               282
# 2       Saraiva    1417.0  1417    Robin  McGuigan               282
# 3  Ansman-Wolfe    1205.0  1205  Sandeep    Katyal               280
# 4      Campbell     517.0   517  Richard    Bready               283
#
#      HireDate
# 0  2011-05-31
# 1  2011-05-31
# 2  2011-05-31
# 3  2011-05-31
# 4  2011-05-31

# %%
name[(pd.Timestamp.now().year - pd.to_datetime(name['HireDate']).dt.year) > 5].head()
# Out:
#    SalesOrderID  SalesPersonID  CustomerID    TotalDue  s_id s_f_name  \
# 0         43660          279.0       29672   1457.3288   279     Tsvi
# 1         43661          282.0       29734  36865.8012   282     José
# 2         43662          282.0       29994  32474.9324   282     José
# 3         43664          280.0       29898  27510.4109   280   Pamela
# 4         43665          283.0       29580  16158.6961   283    David
#
#        s_l_name  PersonID  c_id c_f_name  c_l_name  BusinessEntityID  \
# 0        Reiter     721.0   721   Takiko   Collins               279
# 1       Saraiva     851.0   851    Jauna     Elson               282
# 2       Saraiva    1417.0  1417    Robin  McGuigan               282
# 3  Ansman-Wolfe    1205.0  1205  Sandeep    Katyal               280
# 4      Campbell     517.0   517  Richard    Bready               283
#
#      HireDate
# 0  2011-05-31
# 1  2011-05-31
# 2  2011-05-31
# 3  2011-05-31
# 4  2011-05-31

# %%
# 283 Retrieve the list of product categories along with the total number of products in each category and the average list price, only including categories where the average list price is higher than the overall average list price of all products, sorted by the total number of products in descending order.

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
psc = db_reader().read_table('production.productsubcategory', connection)
psc.head()
# Out:
#    ProductSubcategoryID  ProductCategoryID             Name  \
# 0                     1                  1   Mountain Bikes
# 1                     2                  1       Road Bikes
# 2                     3                  1    Touring Bikes
# 3                     4                  2       Handlebars
# 4                     5                  2  Bottom Brackets
#
#                                 rowguid ModifiedDate
# 0  2D364ADE-264A-433C-B092-4FCBF3804E01   2008-04-30
# 1  000310C0-BCC8-42C4-B0C3-45AE611AF06B   2008-04-30
# 2  02C5061D-ECDC-4274-B5F1-E91D76BC3F37   2008-04-30
# 3  3EF2C725-7135-4C85-9AE6-AE9A3BDD9283   2008-04-30
# 4  A9E54089-8A1E-4CF5-8646-E3801F685934   2008-04-30

# %%
sc = merge().merge_tbl(p[['ProductID', 'ProductSubcategoryID', 'ListPrice']], psc[['ProductSubcategoryID', 'Name','ProductCategoryID']], 'inner','ProductSubcategoryID')
sc.head()
# Out:
#    ProductID  ProductSubcategoryID  ListPrice         Name  ProductCategoryID
# 0        680                  14.0    1431.50  Road Frames                  2
# 1        706                  14.0    1431.50  Road Frames                  2
# 2        707                  31.0      34.99      Helmets                  4
# 3        708                  31.0      34.99      Helmets                  4
# 4        709                  23.0       9.50        Socks                  3

# %%
pc = db_reader().read_table('production.productcategory', connection)
pc.head()
# Out:
#    ProductCategoryID         Name                               rowguid  \
# 0                  1        Bikes  CFBDA25C-DF71-47A7-B81B-64EE161AA37C
# 1                  2   Components  C657828D-D808-4ABA-91A3-AF2CE02300E9
# 2                  3     Clothing  10A7C342-CA82-48D4-8A38-46A2EB089B74
# 3                  4  Accessories  2BE3BE36-D9A2-4EEE-B593-ED895D97C2A6
#
#   ModifiedDate
# 0   2008-04-30
# 1   2008-04-30
# 2   2008-04-30
# 3   2008-04-30

# %%
cat = merge().merge_tbl(pc[['ProductCategoryID','Name']], sc[['ProductSubcategoryID','ProductCategoryID', 'ProductID','ListPrice']], 'inner', 'ProductCategoryID')
cat.head()
# Out:
#    ProductCategoryID   Name  ProductSubcategoryID  ProductID  ListPrice
# 0                  1  Bikes                   2.0        749    146.674
# 1                  1  Bikes                   2.0        750    146.674
# 2                  1  Bikes                   2.0        751    146.674
# 3                  1  Bikes                   2.0        752    146.674
# 4                  1  Bikes                   2.0        753    146.674

# %%
overall = cat['ListPrice'].mean()
overall
# Out:
# 270.19722297297295

# %%
a = cat.groupby(['ProductCategoryID', 'Name']).agg({'ListPrice' : 'mean', 'ProductID' : 'count'}).rename(columns = {'ListPrice': 'avg', 'ProductID' : 'NoOfProducts'}).reset_index().query('avg > @overall').head()
a.head()
# Out:
#    ProductCategoryID        Name         avg  NoOfProducts
# 1                  2  Components  469.860299           134

# %%
# 284 Retrieve the list of employees along with their departments and the total number of orders they've processed, only including employees who have processed more than 50 orders and belong to a department with at least 5 employees, and combine the results with the list of employees who have not processed any orders.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
d = db_reader().read_table('humanresources.department', connection)
d.head()
# Out:
#    DepartmentID         Name                 GroupName ModifiedDate
# 0             1  Engineering  Research and Development   2008-04-30
# 1             2  Tool Design  Research and Development   2008-04-30
# 2             3        Sales       Sales and Marketing   2008-04-30
# 3             4    Marketing       Sales and Marketing   2008-04-30
# 4             5   Purchasing      Inventory Management   2008-04-30

# %%
edh = db_reader().read_table('humanresources.employeedepartmenthistory', connection)
edh.head()
# Out:
#    BusinessEntityID  DepartmentID  ShiftID   StartDate     EndDate  \
# 0                 1            16        1  2009-01-14        None
# 1                 2             1        1  2008-01-31        None
# 2                 3             1        1  2007-11-11        None
# 3                 4             1        1  2007-12-05  2010-05-30
# 4                 4             2        1  2010-05-31        None
#
#   ModifiedDate
# 0   2009-01-13
# 1   2008-01-30
# 2   2007-11-10
# 3   2010-05-28
# 4   2010-05-30

# %%
per = merge().merge_tbl(soh[['SalesOrderID', 'SalesPersonID']], edh[['BusinessEntityID', 'DepartmentID']], 'inner', col1 = 'SalesPersonID', col2 = 'BusinessEntityID')
per.head()
# Out:
#    SalesOrderID  SalesPersonID  BusinessEntityID  DepartmentID
# 0         43660          279.0               279             3
# 1         43661          282.0               282             3
# 2         43662          282.0               282             3
# 3         43663          276.0               276             3
# 4         43664          280.0               280             3

# %%
dept = merge().merge_tbl(per, d[['DepartmentID', 'Name']], 'inner', 'DepartmentID')
dept.head()
# Out:
#    SalesOrderID  SalesPersonID  BusinessEntityID  DepartmentID   Name
# 0         43660          279.0               279             3  Sales
# 1         43661          282.0               282             3  Sales
# 2         43662          282.0               282             3  Sales
# 3         43663          276.0               276             3  Sales
# 4         43664          280.0               280             3  Sales

# %%
dept.groupby(['DepartmentID', 'BusinessEntityID']).agg({'SalesOrderID' : 'count'}).rename(columns = {'SalesOrderID' : 'count_of_o'}).reset_index().query('count_of_o > 50').head()
# Out:
#    DepartmentID  BusinessEntityID  count_of_o
# 1             3               275         450
# 2             3               276         418
# 3             3               277         473
# 4             3               278         234
# 5             3               279         428

# %%
# 285 Retrieve the list of customers who have placed orders along with the list of customers who have not placed orders, combining the results using UNION or UNION ALL to display all customers, and implement pagination to display results in batches of 10 records.

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
cus = db_reader().read_table('sales.customer', connection)
cus.head()
# Out:
#    CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0           2       NaN   1028.0            1    AW00000002
# 1           3       NaN    642.0            4    AW00000003
# 2           4       NaN    932.0            4    AW00000004
# 3           5       NaN   1026.0            4    AW00000005
# 4           6       NaN    644.0            4    AW00000006
#
#                                 rowguid            ModifiedDate
# 0  E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 1  130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 2  FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 3  83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 4  1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263

# %%
new = pd.concat([cus['CustomerID'], soh['CustomerID']])

# %%
new.head()
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# Name: CustomerID, dtype: int64

# %%
# 286 Write a query to retrieve the product names along with a new column "PriceRange" that categorizes products as "Low" if the list price is below $50, "Medium" if between $50 and $100, and "High" if above $100.

p =db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
p['PriceRange'] = None

# %%
p.loc[p['ListPrice'] < 50, 'PriceRange'] = 'Low'

# %%
p.loc[(p['ListPrice'] >= 50) & (p['ListPrice'] <= 100), 'PriceRange'] = 'Medium'

# %%
p.loc[p['ListPrice'] > 100, 'PriceRange'] = 'High'

# %%
p[['ProductID', 'ListPrice', 'PriceRange']].head()
# Out:
#    ProductID  ListPrice PriceRange
# 0          1     1000.0       High
# 1          2        0.0        Low
# 2          3        0.0        Low
# 3          4        0.0        Low
# 4        316        0.0        Low

# %%
# 287 Retrieve the product names and list prices for products with IDs 1, 5, and 10

p =db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
p[p['ProductID'].isin([1,5,10])]
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0          1  Adjustable Race       AR-5381     False              False
#
#   Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  Size  \
# 0  None              1000           750           0.0     1000.0  None
#
#   SizeUnitMeasureCode WeightUnitMeasureCode  Weight  DaysToManufacture  \
# 0                None                  None     NaN                  0
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID SellStartDate  \
# 0        None  None  None                   NaN             NaN    2008-04-30
#
#   SellEndDate DiscontinuedDate                               rowguid  \
# 0         NaT              NaT  694215B7-08F7-4C0D-ACB1-D734BA44C0C8
#
#              ModifiedDate
# 0 2014-02-08 10:01:36.827

# %%
# 288 Get the list of employees whose first name starts with 'J'

col = ['BusinessEntityID',
    'NationalIDNumber',
    'LoginID',
    'OrganizationLevel',
    'JobTitle',
    'BirthDate',
    'MaritalStatus',
    'Gender',
    'HireDate',
    'SalariedFlag',
    'VacationHours',
    'SickLeaveHours',
    'CurrentFlag',
    'rowguid',
    'ModifiedDate']

# %%
emp = db_reader().read_table('humanresources.employee', connection, col)
emp.head()
# Out:
#    BusinessEntityID NationalIDNumber                   LoginID  \
# 0                 1        295847284      adventure-works\ken0
# 1                 2        245797967    adventure-works\terri0
# 2                 3        509647174  adventure-works\roberto0
# 3                 4        112457891      adventure-works\rob0
# 4                 5        695256908     adventure-works\gail0
#
#    OrganizationLevel                       JobTitle   BirthDate MaritalStatus  \
# 0                NaN        Chief Executive Officer  1969-01-29             S
# 1                1.0  Vice President of Engineering  1971-08-01             S
# 2                2.0            Engineering Manager  1974-11-12             M
# 3                3.0           Senior Tool Designer  1974-12-23             S
# 4                3.0                Design Engineer  1952-09-27             M
#
#   Gender    HireDate  SalariedFlag  VacationHours  SickLeaveHours  \
# ...

# %%
per = db_reader().read_table('person.person', connection)
per.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM      False  None       Ken          J
# 1                 2         EM      False  None     Terri        Lee
# 2                 3         EM      False  None   Roberto       None
# 3                 4         EM      False  None       Rob       None
# 4                 5         EM      False   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion AdditionalContactInfo  \
# 0     Sánchez   None               0                  None
# 1       Duffy   None               1                  None
# 2  Tamburello   None               0                  None
# 3     Walters   None               0                  None
# 4    Erickson   None               0                  None
#
#                                         Demographics  \
# 0  <IndividualSurvey xmlns="http://schemas.micros...
# 1  <IndividualSurvey xmlns="http://schemas.micros...
# ...

# %%
name = merge().merge_tbl(emp[['BusinessEntityID']], per[['BusinessEntityID', 'FirstName', 'LastName']], 'inner', 'BusinessEntityID')
name.head()
# Out:
#    BusinessEntityID FirstName    LastName
# 0                 1       Ken     Sánchez
# 1                 2     Terri       Duffy
# 2                 3   Roberto  Tamburello
# 3                 4       Rob     Walters
# 4                 5      Gail    Erickson

# %%
name[name['FirstName'].str.startswith('J')].head()
# Out:
#     BusinessEntityID FirstName  LastName
# 5                  6    Jossef  Goldberg
# 12                13    Janice    Galvin
# 17                18      John      Wood
# 23                24      Jill  Williams
# 24                25     James  Hamilton

# %%
# 289 Retrieve the product names that have no associated product reviews

p =db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
pr =db_reader().read_table('production.productreview', connection)
pr.head()
# Out:
#    ProductReviewID  ProductID  ReviewerName ReviewDate  \
# 0                1        709    John Smith 2013-09-18
# 1                2        937         David 2013-11-13
# 2                3        937          Jill 2013-11-15
# 3                4        798  Laura Norman 2013-11-15
#
#                        EmailAddress  Rating  \
# 0             john@fourthcoffee.com       5
# 1  david@graphicdesigninstitute.com       4
# 2            jill@margiestravel.com       4
# 3            laura@treyresearch.net       5
#
#                                             Comments ModifiedDate
# 0  I can't believe I'm singing the praises of a p...   2013-09-18
# 1  A little on the heavy side, but overall the en...   2013-11-13
# 2  Maybe it's just because I'm new to mountain bi...   2013-11-15
# 3  The Road-550-W from Adventure Works Cycles is ...   2013-11-15

# %%
p[~p['ProductID'].isin(pr['ProductID'])].head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
# 290 Get the list of orders that do not contain products with IDs 15, 20, and 25

sod = db_reader().read_table('sales.salesorderdetail', connection)
sod.head()
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43660                  13          6431-4D57-83         1
# 1         43660                  14          6431-4D57-83         1
# 2         43661                  15          4E0A-4F89-AE         1
# 3         43661                  16          4E0A-4F89-AE         1
# 4         43661                  17          4E0A-4F89-AE         2
#
#    ProductID  SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0        762               1   419.4589                0.0   419.4589
# 1        758               1   874.7940                0.0   874.7940
# 2        745               1   809.7600                0.0   809.7600
# 3        743               1   714.7043                0.0   714.7043
# 4        747               1   714.7043                0.0  1429.4086
#
#                                 rowguid ModifiedDate
# 0  419A1302-AC7A-4044-97B2-66D9D14CD02E   2011-05-31
# ...

# %%
sod[~sod['ProductID'].isin([15, 20, 25])].head()
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43660                  13          6431-4D57-83         1
# 1         43660                  14          6431-4D57-83         1
# 2         43661                  15          4E0A-4F89-AE         1
# 3         43661                  16          4E0A-4F89-AE         1
# 4         43661                  17          4E0A-4F89-AE         2
#
#    ProductID  SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0        762               1   419.4589                0.0   419.4589
# 1        758               1   874.7940                0.0   874.7940
# 2        745               1   809.7600                0.0   809.7600
# 3        743               1   714.7043                0.0   714.7043
# 4        747               1   714.7043                0.0  1429.4086
#
#                                 rowguid ModifiedDate
# 0  419A1302-AC7A-4044-97B2-66D9D14CD02E   2011-05-31
# ...

# %%
# 291 Retrieve the product names and list prices for products with a list price less than $50 and a color of 'Red'

p =db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
p[(p['ListPrice'] > 100) & (p['Color'] == 'Red')].head()
# Out:
#      ProductID                     Name ProductNumber  MakeFlag  \
# 210        706  HL Road Frame - Red, 58    FR-R92R-58      True
# 221        717  HL Road Frame - Red, 62    FR-R92R-62      True
# 222        718  HL Road Frame - Red, 44    FR-R92R-44      True
# 223        719  HL Road Frame - Red, 48    FR-R92R-48      True
# 224        720  HL Road Frame - Red, 52    FR-R92R-52      True
#
#      FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 210               True   Red               500           375     1059.3100
# 221               True   Red               500           375      868.6342
# 222               True   Red               500           375      868.6342
# 223               True   Red               500           375      868.6342
# 224               True   Red               500           375      868.6342
#
#      ListPrice Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# ...

# %%
# 292 Get the list of employees hired between '2005-01-01' and '2008-12-31'

col = ['BusinessEntityID',
    'NationalIDNumber',
    'LoginID',
    'OrganizationLevel',
    'JobTitle',
    'BirthDate',
    'MaritalStatus',
    'Gender',
    'HireDate',
    'SalariedFlag',
    'VacationHours',
    'SickLeaveHours',
    'CurrentFlag',
    'rowguid',
    'ModifiedDate']

# %%
emp = db_reader().read_table('humanresources.employee', connection, col)
emp.head()
# Out:
#    BusinessEntityID NationalIDNumber                   LoginID  \
# 0                 1        295847284      adventure-works\ken0
# 1                 2        245797967    adventure-works\terri0
# 2                 3        509647174  adventure-works\roberto0
# 3                 4        112457891      adventure-works\rob0
# 4                 5        695256908     adventure-works\gail0
#
#    OrganizationLevel                       JobTitle   BirthDate MaritalStatus  \
# 0                NaN        Chief Executive Officer  1969-01-29             S
# 1                1.0  Vice President of Engineering  1971-08-01             S
# 2                2.0            Engineering Manager  1974-11-12             M
# 3                3.0           Senior Tool Designer  1974-12-23             S
# 4                3.0                Design Engineer  1952-09-27             M
#
#   Gender    HireDate  SalariedFlag  VacationHours  SickLeaveHours  \
# ...

# %%
emp[(pd.to_datetime(emp['HireDate']) > '2005-01-01') & (pd.to_datetime(emp['HireDate']) < '2008-12-31')].head()
# Out:
#    BusinessEntityID NationalIDNumber                   LoginID  \
# 1                 2        245797967    adventure-works\terri0
# 2                 3        509647174  adventure-works\roberto0
# 3                 4        112457891      adventure-works\rob0
# 4                 5        695256908     adventure-works\gail0
# 5                 6        998320692   adventure-works\jossef0
#
#    OrganizationLevel                       JobTitle   BirthDate MaritalStatus  \
# 1                1.0  Vice President of Engineering  1971-08-01             S
# 2                2.0            Engineering Manager  1974-11-12             M
# 3                3.0           Senior Tool Designer  1974-12-23             S
# 4                3.0                Design Engineer  1952-09-27             M
# 5                3.0                Design Engineer  1959-03-11             M
#
#   Gender    HireDate  SalariedFlag  VacationHours  SickLeaveHours  \
# ...

# %%
# 293 Retrieve the product names with a list price greater than $100

p =db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
p[p['ListPrice'] > 100].head()
# Out:
#      ProductID                       Name ProductNumber  MakeFlag  \
# 0            1            Adjustable Race       AR-5381     False
# 186        514  LL Mountain Seat Assembly       SA-M198      True
# 187        515  ML Mountain Seat Assembly       SA-M237      True
# 188        516  HL Mountain Seat Assembly       SA-M687      True
# 189        517      LL Road Seat Assembly       SA-R127      True
#
#      FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                False  None              1000           750          0.00
# 186              False  None               500           375         98.77
# 187              False  None               500           375        108.99
# 188              False  None               500           375        145.87
# 189              False  None               500           375         98.77
#
#      ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# ...

# %%
# 294 Write a query to retrieve the product names along with a new column "PriceCategory" that categorizes products as "Budget" if the list price is below $50, "Standard" if between $50 and $100, and "Premium" if above $100

p =db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
p['PriceCategory'] = None

# %%
p.loc[p['ListPrice'] < 50, 'PriceCategory'] = 'Budget'

# %%
p.loc[(p['ListPrice'] >= 50) & (p['ListPrice'] <= 100), 'PriceCategory'] = 'Standard'

# %%
p.loc[p['ListPrice'] > 100, 'PriceCategory'] = 'Premium'

# %%
p[['ProductID', 'ListPrice', 'PriceCategory']].head()
# Out:
#    ProductID  ListPrice PriceCategory
# 0          1     1000.0       Premium
# 1          2        0.0        Budget
# 2          3        0.0        Budget
# 3          4        0.0        Budget
# 4        316        0.0        Budget

# %%
# 295 Retrieve the order IDs along with a new column "OrderStatus" that categorizes orders as "Pending" if the order status is 1, "In Progress" if the status is 2, and "Completed" if the status is 3

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
soh['OrderStatus'] = None

# %%
soh.loc[soh['Status'] ==1, 'OrderStatus'] = 'Pending'

# %%
soh.loc[soh['Status'] ==2, 'OrderStatus'] = 'In Progress'

# %%
soh.loc[soh['Status'] ==3, 'OrderStatus'] = 'Completed'

# %%
soh[['SalesOrderID', 'Status', 'OrderStatus']].head()
# Out:
#    SalesOrderID  Status OrderStatus
# 0         43660       5        None
# 1         43661       5        None
# 2         43662       5        None
# 3         43663       5        None
# 4         43664       5        None

# %%
# 296 Get the list of product names and list prices for products with IDs 2, 6, and 11

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
a = p[p['ProductID'].isin([2,6,11])].head()
a.head()
# Out:
#    ProductID          Name ProductNumber  MakeFlag  FinishedGoodsFlag Color  \
# 1          2  Bearing Ball       BA-8327     False              False  None
#
#    SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  Size  \
# 1              1000           750           0.0        0.0  None
#
#   SizeUnitMeasureCode WeightUnitMeasureCode  Weight  DaysToManufacture  \
# 1                None                  None     NaN                  0
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID SellStartDate  \
# 1        None  None  None                   NaN             NaN    2008-04-30
#
#   SellEndDate DiscontinuedDate                               rowguid  \
# 1         NaT              NaT  58AE3C20-4F3A-4749-A7D4-D568806CC537
#
#              ModifiedDate
# 1 2014-02-08 10:01:36.827

# %%
a[['ProductID', 'Name']]
# Out:
#    ProductID          Name
# 1          2  Bearing Ball

# %%
# 297 Retrieve the order IDs and order dates for orders with IDs 1001, 1005, and 1010

soh = db_reader().read_table('sales.salesorderheader', connection)
soh.head()
# Out:
#    SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0         43660               9 2011-05-20 2011-06-12 2011-06-07       5
# 1         43661               8 2011-05-31 2011-06-12 2011-06-07       5
# 2         43662               8 2011-05-31 2011-06-12 2011-06-07       5
# 3         43663               8 2011-05-31 2011-06-12 2011-06-07       5
# 4         43664               8 2011-05-31 2011-06-12 2011-06-07       5
#
#    OnlineOrderFlag SalesOrderNumber PurchaseOrderNumber   AccountNumber  \
# 0            False          SO43660       PO18850127500  10-4020-000117
# 1            False          SO43661       PO18473189620  10-4020-000442
# 2            False          SO43662       PO18444174044  10-4020-000227
# 3            False          SO43663       PO18009186470  10-4020-000510
# 4            False          SO43664       PO16617121983  10-4020-000397
#
#    CustomerID  SalesPersonID  TerritoryID  BillToAddressID  ShipToAddressID  \
# ...

# %%
soh[soh['SalesOrderID'].isin([1001,1005,1010])]
# Out:
# Empty DataFrame
# Columns: [SalesOrderID, RevisionNumber, OrderDate, DueDate, ShipDate, Status, OnlineOrderFlag, SalesOrderNumber, PurchaseOrderNumber, AccountNumber, CustomerID, SalesPersonID, TerritoryID, BillToAddressID, ShipToAddressID, ShipMethodID, CreditCardID, CreditCardApprovalCode, CurrencyRateID, SubTotal, TaxAmt, Freight, TotalDue, Comment, rowguid, ModifiedDate]
# Index: []

# %%
# 298 Get the list of employee names and titles for employees with titles containing the word 'Manager'

col = ['BusinessEntityID',
    'NationalIDNumber',
    'LoginID',
    'OrganizationLevel',
    'JobTitle',
    'BirthDate',
    'MaritalStatus',
    'Gender',
    'HireDate',
    'SalariedFlag',
    'VacationHours',
    'SickLeaveHours',
    'CurrentFlag',
    'rowguid',
    'ModifiedDate']

# %%
emp = db_reader().read_table('humanresources.employee', connection, col)
emp.head()
# Out:
#    BusinessEntityID NationalIDNumber                   LoginID  \
# 0                 1        295847284      adventure-works\ken0
# 1                 2        245797967    adventure-works\terri0
# 2                 3        509647174  adventure-works\roberto0
# 3                 4        112457891      adventure-works\rob0
# 4                 5        695256908     adventure-works\gail0
#
#    OrganizationLevel                       JobTitle   BirthDate MaritalStatus  \
# 0                NaN        Chief Executive Officer  1969-01-29             S
# 1                1.0  Vice President of Engineering  1971-08-01             S
# 2                2.0            Engineering Manager  1974-11-12             M
# 3                3.0           Senior Tool Designer  1974-12-23             S
# 4                3.0                Design Engineer  1952-09-27             M
#
#   Gender    HireDate  SalariedFlag  VacationHours  SickLeaveHours  \
# ...

# %%
a = emp[emp['JobTitle'].str.contains('Manager')]
a.head()
# Out:
#     BusinessEntityID NationalIDNumber                   LoginID  \
# 2                  3        509647174  adventure-works\roberto0
# 6                  7        134969118    adventure-works\dylan0
# 9                 10        879342154  adventure-works\michael6
# 15                16         24756624    adventure-works\david0
# 25                26        277173473    adventure-works\peter0
#
#     OrganizationLevel                          JobTitle   BirthDate  \
# 2                 2.0               Engineering Manager  1974-11-12
# 6                 3.0  Research and Development Manager  1987-02-24
# 9                 4.0  Research and Development Manager  1984-11-30
# 15                1.0                 Marketing Manager  1975-03-19
# 25                2.0        Production Control Manager  1982-11-03
#
#    MaritalStatus Gender    HireDate  SalariedFlag  VacationHours  \
# 2              M      M  2007-11-11          True              2
# ...

# %%
per = db_reader().read_table('person.person', connection)
per.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM      False  None       Ken          J
# 1                 2         EM      False  None     Terri        Lee
# 2                 3         EM      False  None   Roberto       None
# 3                 4         EM      False  None       Rob       None
# 4                 5         EM      False   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion AdditionalContactInfo  \
# 0     Sánchez   None               0                  None
# 1       Duffy   None               1                  None
# 2  Tamburello   None               0                  None
# 3     Walters   None               0                  None
# 4    Erickson   None               0                  None
#
#                                         Demographics  \
# 0  <IndividualSurvey xmlns="http://schemas.micros...
# 1  <IndividualSurvey xmlns="http://schemas.micros...
# ...

# %%
res = merge().merge_tbl(a[['BusinessEntityID', 'JobTitle']], per[['BusinessEntityID', 'FirstName', 'LastName']], 'inner', 'BusinessEntityID')
res.head()
# Out:
#    BusinessEntityID                          JobTitle FirstName    LastName
# 0                 3               Engineering Manager   Roberto  Tamburello
# 1                 7  Research and Development Manager     Dylan      Miller
# 2                10  Research and Development Manager   Michael      Raheem
# 3                16                 Marketing Manager     David     Bradley
# 4                26        Production Control Manager     Peter       Krebs

# %%
# 299 Retrieve the list of product names for products with names containing the word 'bike'

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
p[p['Name'].str.contains('Bike' ,case= False)]
# Out:
#      ProductID                    Name ProductNumber  MakeFlag  \
# 213        709  Mountain Bike Socks, M     SO-B909-M     False
# 214        710  Mountain Bike Socks, L     SO-B909-L     False
# 380        876     Hitch Rack - 4-Bike       RA-H123     False
# 381        877   Bike Wash - Dissolver       CL-9009     False
# 383        879  All-Purpose Bike Stand       ST-1401     False
# 505       2006             BIKE HANDLE       RV-H123      True
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 213               True  White                 4             3        3.3963
# 214               True  White                 4             3        3.3963
# 380               True   None                 4             3       44.8800
# 381               True   None                 4             3        2.9733
# 383               True   None                 4             3       59.4660
# ...

# %%
# 300 Retrieve the product names that have no associated product images

p = db_reader().read_table('production.product', connection)
p.head()
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0     1000.0  None                None                  None     NaN
# ...

# %%
pp = db_reader().read_table('production.productproductphoto', connection)
pp.head()
# Out:
#    ProductID  ProductPhotoID  Primary ModifiedDate
# 0          1               1     True   2008-03-31
# 1          2               1     True   2008-03-31
# 2          3               1     True   2008-03-31
# 3          4               1     True   2008-03-31
# 4        316               1     True   2008-03-31

# %%
p[~p['ProductID'].isin(pp['ProductID'])]
# Out:
#      ProductID                                   Name ProductNumber  MakeFlag  \
# 504       1001  Vintage Handcrafted Wooden Handlebars      VHWH1000      True
# 505       2006                            BIKE HANDLE       RV-H123      True
#
#      FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 504               True  GOLD                 3             4        6.9223
# 505               True  BLUE               250            20      145.8800
#
#      ListPrice Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 504        8.9    M                 CM                    LB      1.5
# 505     2000.0   20                 CM                    LB      2.0
#
#      DaysToManufacture ProductLine Class Style  ProductSubcategoryID  \
# 504                  1          M     H     U                   23.0
# 505                  0        None  None  None                   NaN
#
#      ProductModelID       SellStartDate         SellEndDate  \
# ...
